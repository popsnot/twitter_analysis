# %% [markdown]
# The purpose of this notebook is to pre-process all our data, which prevents us from having to import it every time we run a new instance of the main notebook. That way, it will be a lot more time-efficient to code in the main notebook.

# %%
# %env PYTHONHASHSEED 3
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !pip install -q pyspark
# Out:
# env: PYTHONHASHSEED=3
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.8/310.8 MB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for pyspark (setup.py) ... done

# %%
def remove_excess(list_of_str):
  problem_chars = "':!.\,/"
  for i in range(0, len(list_of_str)):
    list_of_str[i] = list_of_str[i].rstrip(problem_chars)
  return set(list_of_str)

# %%
from math import sqrt
import pyspark
import os
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession


spark = SparkSession.builder.master("local[*]").appName('Twitter Analysis').config(
    "spark.executor.memory", "1g").config("spark.ui.port", "4050"
        ).getOrCreate()
sc = spark.sparkContext

from google.colab import drive
drive.mount("/content/drive")

influential_users = ['15924858', '14719129', '53235381', '11928542', '215824411', '90880254', '18996905', '262310943', '100318079', '24542441']

feats = sc.textFile('/content/drive/My Drive/twitter_analysis/featnames_rdd.txt')
feats = feats.map(lambda x: (x.split(", ")[1].split('r/')[1].split('.')[0], x.split(", ")[0].split(" ")[1])).groupByKey().filter(lambda x: x[0] in influential_users).mapValues(list).map(lambda x: (x[0], remove_excess(x[1])))
# Out:
# Mounted at /content/drive

# %%
import math

def length(vector):
    sum_sq = 0
    for item in vector:
      sum_sq += int(item)*int(item)
    return math.sqrt(sum_sq)

def cosine_similarity(u, v):
      dotprod = sum(int(i[0]) * int(i[1]) for i in zip(u, v))
      return dotprod/(length(u) * length(v))

# %%
#feats.count()
#feats = feats.map(lambda x: (x.split(",")[1], x.split(",")[0]).take(10)
#feats#.map(lambda x: (x.file_path.split('r/')[1].split('.')[0], x.value.split()[1])).groupByKey().mapValues(list)

# %%
feats.take(10)
# Out:
# [('333881828',
#   {'#1',
#    '#FF',
#    '#RT',
#    '@AlyMew',
#    '@B_Loner',
#    '@ChillTreehugger',
#    '@ClubbyDubby',
#    '@DanielHyon',
#    '@DavidVonderhaar',
#    '@EMPTECLIP5E',
#    '@EatMyDiction1',
#    '@FuzzyOtterBalls',
#    '@FxyMxy',
#    '@GoldGloveTV',
#    '@IMortaLTechNyQ',
#    '@KittyRavage',
#    '@Klutch7',
#    '@LethalFrag',
#    '@Mal_Mal2011',
#    '@Meatholl',
#    '@MediocreMadame',
#    '@MistaCheapSkate',
#    '@MousePena',
#    '@MrAran551',
#    '@MrErnestLe',
#    '@MrsExile',
#    '@MsArtemis01',
#    '@NasaFromNYC',
#    '@OhShit_ItsBerlo',
#    '@Peopleschamp330',
#    '@Pewdie',
#    '@Phantom_Legend',
#    '@Puddock3000',
#    '@Pwnedbyagiirl',
#    '@QuakeBeatZ',
#    '@Sarcasmx',
#    '@Schoolyy',
#    '@ShiftHappensBro',
#    '@Shino775',
#    '@Siggyv',
#    '@Sinumatic',
#    '@SoCalMeg',
#    '@SwagChica',
#    '@TheKingNappy',
#    '@The_SilviaKid',
#    '@Tiffababyy',
#    '@TmarTn',
#    '@UnlawfulExile',
#    '@VegasJamie',
#    '@WGUnite',
#    '@Yeousch',
#    '@YouTube',
#    '@Zerosion',
#    '@_TwitTwit',
#    '@aWhitebrownie',
#    '@alymew',
#    '@bigsnackks',
#    '@daniTHEdynamo',
#    '@diggity19',
#    '@e2unes',
#    '@hiHedski',
#    '@iAmLauRawr',
#    '@iBeWonKa',
#    '@insanexvixen',
#    '@kween1thang',
#    '@luxxeh',
#    '@sinumatic',
#    '@swaytuned',
#    '@thezombiekitty',
#    '@vegasjamie',
#    '@wak4863',
#    '@xGetEmGurlx',
#    '@xKingXero',
#    '@xShananiGUNS',
#    '@xSmilesss',
#    '@xsmilesss',
#    '@yeousch',
#    '@youtube'}),
#  ('345569115',
#   {'#1',
#    '#2',
#    '#3',
#    '#BF3',
#    '#BackInElementarySchool',
#    '#BlackOps',
#    '#BlackOps2',
#    '#BlacksOps2',
#    '#Blops2',
#    '#Borderlands',
#    '#COD',
#    '#CallOfDuty',
#    '#CoDElite',
#    '#FF',
#    '#HappyWHeels',
#    '#InMiddleSchool',
#    '#LoveMyJob',
#    '#MW3',
#    '#PENIS',
#    '#PS3',
#    '#RT',
#    '#RealFuckers',
#    '#SMH',
#    '#SayNoToDrugsSayYesToGaming',
#    '#TPwn',
#    '#TPwnFamily',
#    '#ThingsThatGetYouFriendZoned',
#    '#UMGClassic',
#    '#YOLO',
#    '#blackops2',
#    '#cod',
#    '#derp',
#    '#ff',
#    '#halo4',
#    '#ilovethischick',
#    '#instantbackfollow',
#    '#ps3',
#    '#realspit',
#    '#sick',
#    '#smh',
#    '#whounfollowedme',
#    '#yolo',
#    '@',
#    '@2SikTv',
#    '@4N0Y3D',
#    '@7pm',
#    '@ABK_Laggy_Host',
#    '@APixelatedMind',
#    '@AeroSpaceGuy93',
#    '@AlyMew',
#    '@AmerikanInfidel',
#    '@AriaAspen',
#    '@AustinDizzy',
#    '@B_Loner',
#    '@BdyDrpdKotaEC',
#    '@Bigal4242',
#    '@Bigcountry77x',
#    '@Bing8778',
#    '@BlackOps_Tips',
#    '@BlyArctrooper',
#    '@Bonfiggy',
#    '@CallOfDutyElite',
#    '@CallofDuty',
#    '@CannibalBacon',
#    '@Capt_Hawkeye',
#    '@CatF1ght',
#    '@Chaosxsilencer',
#    '@CharlesSu2uki',
#    '@ChillTreehugger',
#    '@ChocSoulBrutha',
#    '@Choopaloopa',
#    '@ChucklesGaming',
#    '@ClubbyDubby',
#    '@Cnasty006',
#    '@ColinThaGreat',
#    '@ComicalDisaster',
#    '@CoryBlocker',
#    '@CoryWho',
#    '@CraigMaster',
#    '@CrazyKarateMnky',
#    '@CrystalKM',
#    '@Cuiusofcaelum',
#    '@Cursed_Ns',
#    '@DJWordless',
#    '@DamnItsMatt',
#    '@DanielHyon',
#    '@Danimillion',
#    '@DarthChronikus',
#    '@Darth_Icarus',
#    '@DavidVonderhaar',
#    '@DmanUnt2014',
#    '@DougieFr3sh3',
#    '@DrChiz',
#    '@Drift0r',
#    '@Dy5function',
#    '@EMPTECLIP5E',
#    '@EnViious_',
#    '@FIRESOFCLARITY',
#    '@FaZeClan',
#    '@Famous_king',
#    '@FantasticV_eHm',
#    '@FayyTal',
#    '@FearCrads',
#    '@Fossil16',
#    '@FrankSoBlunt',
#    '@FruntIine',
#    '@FuzzyOtterBalls',
#    '@FxyMxy',
#    '@GFXLAB',
#    '@GameTrailers',
#    '@GetGlue',
#    '@GhostIRequiem',
#    '@Gizmodo',
#    '@GlitchZero',
#    '@Gmg523',
#    '@GoldGloveTV',
#    '@GracieLOLiver',
#    '@Greenbu',
#    '@Greenbullet_',
#    '@GuudeLP',
#    '@IAmSp00n',
#    '@IGN',
#    '@IIJERiiCHOII',
#    '@IMortaLTechNyQ',
#    '@ImGrover',
#    '@ImJocavs',
#    '@IrishTricks',
#    '@ItsYouTubeDude',
#    '@Its_Jakeee',
#    '@JOswlad',
#    '@JaimeR_',
#    '@JazzyPanda7',
#    '@Jimusmc',
#    '@JoeDavisKU',
#    '@JordanN9ne',
#    '@JordanN9ne\'s"',
#    '@JustCindeh',
#    '@KKatera',
#    '@KaJePlays',
#    '@KiddSlauda',
#    '@Killamckiller',
#    '@KingHoward_',
#    '@KittyRavage',
#    '@Kootra',
#    '@KrisBallin305',
#    '@KushDoll',
#    '@LMFAoSusie',
#    '@LeatherBelt5',
#    '@Lenam80',
#    '@LethalFrag',
#    '@LimitdLiability',
#    '@LuCiG3N',
#    '@LuminousGFX',
#    '@Mal_Mal2011',
#    '@MarkMorbidity',
#    '@MasvSolarStorm',
#    '@MayhemMurder',
#    '@MediocreMadame',
#    '@MeganLena',
#    '@MelonOwnz',
#    '@MensHumor',
#    '@Mikehtx',
#    '@MinnesotaBurns',
#    '@MissZombieLady',
#    '@Missfifilopez',
#    '@MistaCheapSkate',
#    '@MonJarek',
#    '@MousePena',
#    '@MrAran551',
#    '@MrITryHard',
#    '@MrsExile',
#    '@MsArtemis01',
#    '@MsMarcy34',
#    '@MsMurderMonroe',
#    '@NBA',
#    '@NINAtheBOSSxo',
#    '@NandoPTG',
#    '@NasaFromNYC',
#    '@NickAbc423',
#    '@NuketownNoob',
#    '@ONLYUSEmeBLADE',
#    '@ObviouslyNancy',
#    '@OhShit_ItsBerlo',
#    '@OpTicH3CZ',
#    '@OpTicMiDNiTE',
#    '@OptimusMagnum',
#    '@PBrasfieldATO',
#    '@POPPKELL',
#    '@PROTIPZ',
#    '@Peopleschamp330',
#    '@Phantom_Legend',
#    '@PhillyRampage',
#    '@Ploofy',
#    '@Pr0_HaTTa',
#    '@Puddock3000',
#    '@Pwnedbyagiirl',
#    '@QuakeBeatZ',
#    '@QuiKGunZ',
#    '@RAVENOUSKELLS',
#    '@ROCCITY4life',
#    '@Rambo513',
#    '@Renacide',
#    '@RickyChops',
#    '@RpDeAdLy541',
#    '@STONE5572',
#    '@Sagesparten007',
#    '@Sarcasmx',
#    '@Sawcasm',
#    '@Sean_Zulu',
#    '@ShakeDown2012',
#    '@ShawnMichaels',
#    '@SheeGee',
#    '@Shino775',
#    '@Siggyv',
#    '@SikChick360',
#    '@Sing2Bucks',
#    '@SinnersMyth',
#    '@Sinumatic',
#    '@SoCalMeg',
#    '@SoCalVinnyVee',
#    '@SpasMyDogs',
#    '@Spawn_Trap',
#    '@SuckMySpork',
#    '@SwagChica',
#    '@TCPow',
#    '@TPwnElite',
#    '@TPwnMedia',
#    '@TaverasN',
#    '@TeamPwnage',
#    '@Tfetterolf456',
#    '@TheDeceptive',
#    '@TheDoofa',
#    '@TheFDchick',
#    '@TheIlluminati',
#    '@TheKingNappy',
#    '@TheMIXXRadio',
#    '@TheOceaneOpz',
#    '@ThePsychal',
#    '@TheRealRon1224',
#    '@Thelazyone78',
#    '@ThirdEyeSnipers',
#    '@ThunderS7ruck',
#    '@Tiffababyy',
#    '@TmarTn',
#    '@Tougeznut',
#    '@Tr1ckpoker',
#    '@Treyarch',
#    '@Twistedsoul1020',
#    '@TwitchTV',
#    '@UTxJGTheDon',
#    '@UTxSHaXb0tzAm',
#    '@UberFacts',
#    '@VegasJamie',
#    '@Vickyx34',
#    '@WGUnite',
#    '@WORICP',
#    '@Weeeezi',
#    '@Whiteboy7thst',
#    '@WoodysGamertag',
#    '@XSTROLOGY',
#    '@XZChick',
#    '@Xx334xX',
#    '@Xxplosions',
#    '@YOTESLAYA',
#    '@Y_Reloaded',
#    '@Yeousch',
#    '@YouTube',
#    '@YungCE0',
#    '@Zerosion',
#    '@ZevHadar',
#    '@Zobernuts',
#    '@_LegendOfGamer',
#    '@_TwitTwit',
#    '@_twittwit',
#    '@_whitebizz',
#    '@aWhitebrownie',
#    '@airtech62',
#    '@akaRachelK',
#    '@akarachelk',
#    '@alymew',
#    '@apadilla505',
#    '@arnimane',
#    '@baef',
#    '@bapdawg',
#    '@beachheadstudio',
#    '@beastradamus',
#    '@bestbuy',
#    '@bigcountry77x',
#    '@bigsnackks',
#    '@browland1',
#    '@bunnyXablaze',
#    '@chaosxsilencer',
#    '@charlieINTEL',
#    '@clanBAB',
#    '@cnasty006',
#    '@cutterbups',
#    '@daniTHEdynamo',
#    '@danithedynamo',
#    '@dannybabe19',
#    '@darkhawk1126',
#    '@deadmau5',
#    '@deathlyiam',
#    '@deysirivera',
#    '@diggity19',
#    '@dutchyDC',
#    '@dxman830',
#    '@e2unes',
#    '@emarati_96',
#    '@fayytal',
#    '@fossil16',
#    '@glitchzero',
#    '@gmg523',
#    '@hiHedski',
#    '@hyperkind808',
#    '@iAmLauRawr',
#    '@iBeWonKa',
#    '@iCn_Brian',
#    '@iLikeGirlsDaily',
#    '@iPwnstar4hire',
#    '@illicitFLOWER',
#    '@insanexvixen',
#    '@its_jakeee',
#    '@itzFeAr_d',
#    '@jaimer_',
#    '@jamier_',
#    '@jawssslyn',
#    '@jordann9ne',
#    '@josephespino',
#    '@juliocontrera12',
#    '@kaykaykasey17',
#    '@kiranearitachi',
#    '@kittyravage',
#    '@kranktone',
#    '@krisballin305',
#    '@krmasabtch',
#    '@krystipryde',
#    '@kween1thang',
#    '@luxxeh',
#    '@manynukes11',
#    '@me',
#    '@mongstradamus',
#    '@mrbr1zzo',
#    '@myccxoxo',
#    '@nandoptg',
#    '@ogwalrus',
#    '@ohmygeri',
#    '@pacifictomb',
#    '@passthemstickss',
#    '@pinkbeauty357',
#    '@quikgunz',
#    '@rds999_',
#    '@rondre3000',
#    '@socalmeg',
#    '@soxwithpotatoes',
#    '@stfuthnx',
#    '@suckmyspork',
#    '@swaytuned',
#    '@swizzcheezs',
#    '@taverasn',
#    '@tcpow',
#    '@tdog91184',
#    '@teampwnage',
#    '@texasxdro',
#    '@theEpidemic17',
#    '@thekingnappy',
#    '@themissesmae',
#    '@themonstergamer',
#    '@thezombiekitty',
#    '@tiffababyy',
#    '@tougeznut',
#    '@twaffs',
#    '@twistedsoul1020',
#    '@uMadBro_96',
#    '@vegasjamie',
#    '@victortristan',
#    '@wak4863',
#    '@wickedshrapnel',
#    '@xB1ackFire',
#    '@xGetEmGurlx',
#    '@xIlluminaudio',
#    '@xJaredSykes',
#    '@xJawz',
#    '@xKingXero',
#    '@xMurderCutex',
#    '@xShananiGUNS',
#    '@xSmilesss',
#    '@xStrangeLuvx',
#    '@xX_SamKulii_Xx',
#    '@xbadassbeauty',
#    '@xjade1358x',
#    '@xsmashx88x',
#    '@xsmilesss',
#    '@y_reloaded',
#    '@yeousch',
#    '@youtube',
#    '@z0mgItsHutch'}),
#  ('18996905',
#   {'#1',
#    '#11',
#    '#12',
#    '#2',
#    '#3',
#    '#4',
#    '#AskMaydayParade',
#    '#Brier',
#    '#Bulls',
#    '#Bullstock',
#    '#FBR15',
#    '#FBRHolidaySale',
#    '#FBRPhotos',
#    '#FBRmoments',
#    '#FF',
#    '#Gay',
#    '#KILLERCOLLABOS',
#    '#KONY2012',
#    '#LGBT',
#    '#NYC',
#    '#NowPlaying',
#    '#PMA',
#    '#RSD',
#    '#StrangeClouds',
#    '#USF',
#    '#VansWarpedTour',
#    '#VersaEmerge',
#    '#WearYourParamoreShirtDay',
#    '#beyondfamous',
#    '#fbrphotos',
#    '#foodtweets',
#    '#karmaloopTV',
#    '#panicatthedisco',
#    '#paramore',
#    '#parastream',
#    '#priorities',
#    '#shitthomsays',
#    '#somenights',
#    '#thatawkwardmoment',
#    '#thesoundofquality',
#    '#thevoice',
#    '#weareyoung',
#    '@',
#    '@1027KIISFM',
#    '@7:30',
#    '@987LA',
#    '@ARTTM',
#    '@AlexAllTimeLow',
#    '@AlliRamen',
#    '@AltPress',
#    '@AmazonMP3',
#    '@AmericanExpress',
#    '@AndrewWK',
#    '@Andrewgoldstein',
#    '@AnthonyGreen',
#    '@Ashanti',
#    '@Beartrick',
#    '@Betatraxx',
#    '@BlakeVE',
#    '@BrendonBoydUrie',
#    '@CS_Mexico',
#    '@CaitlinDyess',
#    '@ChrisTFT',
#    '@CobraStarship',
#    '@CobusPotgieter',
#    '@ComplexMag',
#    '@DallonWeekes',
#    '@DanFBR',
#    '@DannyHutto',
#    '@DecentlyFunny',
#    '@Drake',
#    '@Eliza_Coupe',
#    '@ErinMarie37',
#    '@FBRWebstore',
#    '@FUSETV',
#    '@FeedOurChildren',
#    '@Fellmanator',
#    '@FoxyShazam\'s"',
#    '@Fueled',
#    '@FueledByRamen',
#    '@FueledByRamen\'s"',
#    '@GLAAD',
#    '@GabrielSaporta',
#    '@GetGlue',
#    '@Glenwood',
#    '@GymClassEric\'s"',
#    '@GymClassHeroes',
#    '@HotTopic',
#    '@HuffingtonPost',
#    '@Invisible',
#    '@ItHipScene',
#    '@JayDrummerBoy',
#    '@JayLeno',
#    '@JayLenoTonight',
#    '@JulietSimmsALL',
#    '@KROQ',
#    '@KatieRamen',
#    '@KillerQueenMCR',
#    '@KyleKorver',
#    '@Late_Show',
#    '@LindaIgnarro',
#    '@MBradleyG',
#    '@MTV',
#    '@MTV\'s"',
#    '@MTVBuzzworthy',
#    '@MacMiller',
#    '@MaxBemis',
#    '@MaydayParde',
#    '@Mayday_Parade',
#    '@MikeSheaAP',
#    '@MrAndrewDawson',
#    '@MuchMusic',
#    '@NBCTheVoice',
#    '@NEWBROOKLAND',
#    '@NML',
#    '@NeonHitch',
#    '@NicholeWeber',
#    '@NickSantino',
#    '@NovarroNate',
#    '@OhWonka',
#    '@OneRepublic',
#    '@OurNameIsFun',
#    '@PS22Chorus',
#    '@PanicAtTheDisco',
#    '@ParaScots',
#    '@ParamoreBrazil',
#    '@ParamoreCity',
#    '@ParamoreEh',
#    '@ParamoreFB',
#    '@Paramoreans',
#    '@PlaceAuxErycka',
#    '@QuiteRomantic',
#    '@RealWizKhalifa',
#    '@RecordStoreDay',
#    '@ReelBearMedia',
#    '@RollingStone',
#    '@RomeMusica',
#    '@RyBlackinton',
#    '@RyBlackinton\'s"',
#    '@RyaBacker',
#    '@SUAREASY',
#    '@SabiSoundz',
#    '@SashOnAPlane',
#    '@Savesthedave',
#    '@SayAnythingMuz',
#    '@SayAnythingMuz\'s"',
#    '@Selkoe',
#    '@SequoyahMusic',
#    '@SierraVE',
#    '@Spotify',
#    '@Stageit',
#    '@StevenJBattelle',
#    '@SublimeWithRome',
#    '@The',
#    '@TheBamboozle',
#    '@TheBeierMann',
#    '@TheDavidBlaise',
#    '@TheIanCrawford',
#    '@TheRyanAdams',
#    '@TheSilverComet',
#    '@TheSilverComet\'s"',
#    '@TheSpencerSmith',
#    '@TheSwellers',
#    '@ThisProvidence',
#    '@TravieMcCoy',
#    '@TravisZachary',
#    '@TwittaParamore',
#    '@USF',
#    '@UberFacts',
#    '@UltimateEars',
#    '@UltimateGabeS',
#    '@ValeGoRandom_',
#    '@VansWarpedTour',
#    '@VersaEmerge',
#    '@VictoriaJAsher',
#    '@VictoriaJAsher?',
#    '@WWEMusic',
#    '@WileyEsten',
#    '@XChadballX',
#    '@Y100MIAMI',
#    '@YourParamore',
#    '@ZackCloudHall',
#    '@_theguy_',
#    '@_zigga',
#    '@absolutepunk',
#    '@adamlevine',
#    '@ahouseofwolves',
#    '@alliramen',
#    '@amanapants',
#    '@amyramen',
#    '@anderson_eric',
#    '@andrewdost',
#    '@andrewtothemoon',
#    '@andy_john',
#    '@animalupstairs',
#    '@arttm',
#    '@atothemak',
#    '@awphotographs',
#    '@benabary',
#    '@billbeckett',
#    '@blakefoster',
#    '@blakeve',
#    '@bobatl\'s"',
#    '@boycottl0ve',
#    '@brendonboydurie',
#    '@brianlogandales',
#    '@briansouthall',
#    '@butchwalker',
#    '@camillealston',
#    '@carlyraejepsen',
#    '@charlavail',
#    '@chrisfarren',
#    '@clandestinerain',
#    '@cobrastarship',
#    '@craigowens',
#    '@crossesmusic',
#    '@danfbr',
#    '@detroitpistons',
#    '@disashi',
#    '@dustinaddis',
#    '@eazy_ej',
#    '@elektrarecords',
#    '@erichalvorsen',
#    '@evanwiniker',
#    '@fbrstreetteam',
#    '@fearlessradio',
#    '@folieajade',
#    '@fouryearstrong',
#    '@foxyshazam',
#    '@fueledbyadam',
#    '@fueledbymelissa',
#    '@fueledbyramen',
#    '@fueledbyramen.com',
#    '@fyeguy',
#    '@gabrielsaporta',
#    '@galeamonster',
#    '@garrettmaine',
#    '@gaslightanthem',
#    '@glamourkills',
#    '@gmail.com',
#    '@gonicko',
#    '@gymclasseric',
#    '@gymclassheroes',
#    '@haayitstaay',
#    '@hansonmusic',
#    '@hellosarahsays',
#    '@htlnick',
#    '@iTunes',
#    '@iTunesMusic',
#    '@iTunesmusic',
#    '@intoitoverit',
#    '@itshellogoodbye',
#    '@itstayloryall',
#    '@itunesmusic',
#    '@ivytyler',
#    '@jackantonoff',
#    '@jacksmannequin',
#    '@jacobgivens',
#    '@jacvanek',
#    '@jason_tate',
#    '@jeffreytonnesen',
#    '@jennylsq',
#    '@jodiCLT',
#    '@johnnyminardijr',
#    '@jonodiener',
#    '@joshterryaware',
#    '@joshuadun',
#    '@justinbrighten',
#    '@justinmj',
#    '@karmaloop',
#    '@katieramen',
#    '@keepabreast',
#    '@kiddenz',
#    '@kyleisez',
#    '@lindaignarro',
#    '@lostprophets',
#    '@marcdejesus',
#    '@marianasatierf',
#    '@markceshleman',
#    '@matthewmcginley',
#    '@mattydookis',
#    '@meganaberle',
#    '@meganamram',
#    '@megatronGFU',
#    '@megatrongfu',
#    '@mindywhite',
#    '@mrdavehill',
#    '@mtv',
#    '@musicchoice',
#    '@myedgelife',
#    '@mynameisjonah',
#    '@myspace',
#    '@nanotissera',
#    '@nathenmcvittie',
#    '@neiltyson',
#    '@nicksantino',
#    '@nicksmith417',
#    '@nickthehobo',
#    '@nodoubt',
#    '@noisecreep',
#    '@ocdustino',
#    '@ourcounterparts',
#    '@ournameisfun',
#    '@panicatthedisco',
#    '@parahani',
#    '@paramore',
#    '@patrickstump',
#    '@petewentz',
#    '@pinterest',
#    '@porters',
#    '@quietstorm_32',
#    '@rachelantonoff',
#    '@raul_gonzo',
#    '@raulgonzo',
#    '@rcrdlbl',
#    '@reganzajac',
#    '@rejoicedonnie',
#    '@ryblackinton',
#    '@s4r4hsux',
#    '@savesthedave',
#    '@schzimmydeanie',
#    '@scottheisel',
#    '@shanevaldes',
#    '@shannonforecast',
#    '@shaunlopez',
#    '@shutterspeeds',
#    '@sierrave',
#    '@sille_enilorac',
#    '@siskybusiness',
#    '@smallzy',
#    '@stageit',
#    '@startswithwill',
#    '@stereojorge',
#    '@stevefoy1',
#    '@stickam',
#    '@suareasy',
#    '@sublimewithrome',
#    '@swrv_tv',
#    '@taylorswift13',
#    '@teganandsara',
#    '@thanhechelon',
#    '@thatgirlveethoo',
#    '@theNuzzy',
#    '@theforecast',
#    '@thejimmybreen',
#    '@themaine',
#    '@therealTREOS',
#    '@therejects',
#    '@thesulk',
#    '@thomasdurden',
#    '@timwilliam',
#    '@titlefight',
#    '@twentyonepilots',
#    '@tylerinacoma',
#    '@tylerpursel',
#    '@tylerrjoseph',
#    '@vera3oh_ate',
#    '@victoriajasher',
#    '@vipes',
#    '@willnoon',
#    '@xryanrussellx',
#    '@yelyahwilliams',
#    '@zachwahls'}),
#  ('14719129',
#   {'#',
#    '#1',
#    '#3',
#    '#4sqDay',
#    '#Avengers',
#    '#CoachellaLive',
#    '#ComicBookMen',
#    '#Community',
#    '#DRTV',
#    '#DoctorWho',
#    '#Enterprise',
#    '#FF',
#    '#PDX',
#    '#SFGiants',
#    '#TWD',
#    '#TheWalkingDead',
#    '#WalkingDead',
#    '#Yelp',
#    '#cars',
#    '#chocolate',
#    '#fail',
#    '#fb',
#    '#ff',
#    '#flickr',
#    '#food',
#    '#get3',
#    '#hype',
#    '#ipad',
#    '#ipad3',
#    '#lastfm',
#    '#motorcycle',
#    '#new',
#    '#peanutbutter',
#    '#photography',
#    '#respect',
#    '#scotch',
#    '#spottheshuttle',
#    '#studieag',
#    '#sworcery',
#    '#sxsw',
#    '#throwback',
#    '@',
#    '@500px',
#    '@84play',
#    '@AMCTalkingDead',
#    '@Adobe',
#    '@AlbiTebaldi',
#    '@Anelf3',
#    '@AskBuxley',
#    '@AussieGrit',
#    '@Beatweek',
#    '@BeltramoPaolo',
#    '@BenSpies11',
#    '@BerryLowman',
#    '@BillCorbett',
#    '@BloodyProducer',
#    '@BobMcBob',
#    '@Boulevard',
#    '@CRtwotwo',
#    '@CheapyD',
#    '@Coverville',
#    '@Cranky_Hippo',
#    '@Crazy4ComicCon',
#    '@Dan_H',
#    '@DanaWollman',
#    '@Davide_Brivio',
#    '@Doctoreddu46',
#    '@Doylecomic',
#    '@EngadgetDistro',
#    '@Engadget”',
#    '@FieryPinkGirl',
#    '@ForbesTech',
#    '@Gabbia74',
#    '@GenkiGenki',
#    '@GetGlue',
#    '@GlennRubenstein',
#    '@GraggBurnett',
#    '@HellForLeather',
#    '@IGN',
#    '@ImTracyMorgan',
#    '@JLin7',
#    '@JReckitt',
#    '@Jacksonfly',
#    '@Jimwhit69',
#    '@JoannaStern',
#    '@JonStrickland',
#    '@JustinRYoung',
#    '@Kickstarter',
#    '@LaurenCohan',
#    '@LilCoderBaby',
#    '@Lizard77_',
#    '@LucaFilippiLF',
#    '@Matt_Alt',
#    '@McWill99',
#    '@MelodyMcC',
#    '@MikeNC629',
#    '@MostAgreeable',
#    '@MrScottFletcher',
#    '@Nehalia',
#    '@NeilHodgson100',
#    '@New',
#    '@NickyHayden69',
#    '@NotPatrick',
#    '@Official_CS27',
#    '@PFTompkins',
#    '@PhatEmoKid',
#    '@Pho',
#    '@Pinterest',
#    '@Reddingpower',
#    '@RobertKirkman',
#    '@RobertoBrivio',
#    '@SFGiants',
#    '@SFist',
#    '@San',
#    '@ScottKelby',
#    '@ShaneWatch',
#    '@Snubs',
#    '@Spalders',
#    '@Starbucks',
#    '@TWiT',
#    '@TWiTGameOn',
#    '@Taqueria',
#    '@TechCrunch',
#    '@Terminal',
#    '@TexasJeffW',
#    '@The',
#    '@TheCakeWolf',
#    '@TheNextWeb',
#    '@ThePeterHa',
#    '@TheTrekNerd',
#    '@The_T',
#    '@ToucanMonkey',
#    '@TreyRatcliff',
#    '@UccioYellow46',
#    '@ValeYellow46',
#    '@Vance14',
#    '@Veronica',
#    '@WalkingDead_AMC',
#    '@WaltRibeiro',
#    '@YouTube',
#    '@abc7newsBayArea',
#    '@acarboni',
#    '@acedtect',
#    '@akaTRENT',
#    '@akumatose',
#    '@alexia',
#    '@alexlindsay',
#    '@altosop',
#    '@amazonvideo',
#    '@amtrekker',
#    '@andreaiannone29',
#    '@anthonyha',
#    '@antonioboselli',
#    '@ashonbikes',
#    '@azizansari',
#    '@backlon',
#    '@benspies11',
#    '@billmeeks',
#    '@blam',
#    '@bonniegrrl',
#    '@bosun120',
#    '@brandondphotos',
#    '@brendonbeyond',
#    '@bworley',
#    '@c_davies',
#    '@calcrutchlow',
#    '@canonrumorsguy',
#    '@chasejarvis',
#    '@chasejarvis)',
#    '@chazdavies',
#    '@christyxcore',
#    '@comiXology',
#    '@copelandbrent',
#    '@core77',
#    '@cpen',
#    '@davecross',
#    '@daynah',
#    '@designtaxi',
#    '@digitalrev',
#    '@dondanielelaghi',
#    '@dragonal',
#    '@eileentv',
#    '@emailforhelp',
#    '@eneosusa',
#    '@engadget',
#    '@erickimphoto',
#    '@f5torefresh',
#    '@feitclub',
#    '@feliciaday',
#    '@flySFO)',
#    '@foursquare',
#    '@futurepaul',
#    '@gaberivera',
#    '@giantbomb',
#    '@ginatrapani',
#    '@glenmazzara',
#    '@grahamhancock',
#    '@hawaii',
#    '@hawkito',
#    '@hiroko84',
#    '@hotmilkgt',
#    '@hulu',
#    '@iconmotosports',
#    '@iomatrix23',
#    '@iyaz',
#    '@j_per3z',
#    '@jakeadelstein',
#    '@jamesmielke',
#    '@jasonhowell',
#    '@jasontucker',
#    '@jawboneradio',
#    '@jeansnow',
#    '@jeffjarvis',
#    '@john_blanton',
#    '@johnjohanas',
#    '@johnnythefuture',
#    '@johntv',
#    '@jollyroger',
#    '@jonfingas',
#    '@jontilton',
#    '@joshuatopolsky',
#    '@justinryoung',
#    '@jwherrman',
#    '@kaimanwong',
#    '@kayakchick',
#    '@kazamatsuri',
#    '@klout',
#    '@kumailn',
#    '@leolaporte',
#    '@lexysavvides',
#    '@lilcoderbaby',
#    '@lokcheung',
#    '@lorenzo99',
#    '@lucafilippilf',
#    '@marco_parc',
#    '@markmacd',
#    '@mashable',
#    '@mateospag',
#    '@mattiapasini',
#    '@mattrobertsbbc',
#    '@mflamigni',
#    '@mikeschramm',
#    '@missiondeep',
#    '@mollywood',
#    '@monkeystick',
#    '@moto_ink',
#    '@mshoe',
#    '@neiltyson',
#    '@nerdist',
#    '@nicolespag',
#    '@nkasu',
#    '@omgchad',
#    '@padresj',
#    '@parislemon',
#    '@patrickklepek',
#    '@patricknorton',
#    '@paunchstevenson',
#    '@peach_',
#    '@petapixel',
#    '@phonescooper',
#    '@ptorno',
#    '@radiocolin',
#    '@reckless',
#    '@renetetrault',
#    '@richardlai',
#    '@robertkirkman',
#    '@romanymalco',
#    '@ronxo',
#    '@russpitts',
#    '@ryan',
#    '@ryanpayton',
#    '@samjane',
#    '@sandmansandine',
#    '@sarahlane',
#    '@scbound',
#    '@scottjohnson',
#    '@scottsigler',
#    '@shawncoons',
#    '@shwood',
#    '@simoncrafar',
#    '@sprsk',
#    '@steveyeun',
#    '@suda_51',
#    '@swordandlaser',
#    '@the_t',
#    '@thebmatt',
#    '@theclichebrand',
#    '@thegogame',
#    '@thekenyeung',
#    '@thomashawk',
#    '@thurrott',
#    '@tnkgrl',
#    '@tomgehrke',
#    '@tommerritt',
#    '@twit',
#    '@twitlive',
#    '@ural_twit',
#    '@verge',
#    '@verge)',
#    '@veronica',
#    '@vladsavov',
#    '@wilw',
#    '@wired',
#    '@youtube',
#    '@zefrank',
#    '@zendogmedia',
#    '@zpower',
#    '@成田国際空港'}),
#  ('73298877',
#   {'#',
#    '#1',
#    '#3',
#    '#BringBackToonami',
#    '#FF',
#    '#NP',
#    '#SXSW',
#    '#Skullgirls',
#    '#Spotify',
#    '#YOLO',
#    '#chiptune',
#    '#ff',
#    '#music',
#    '#np',
#    '#thatisall',
#    '@AndrewWK',
#    '@AreciboRadio',
#    '@Art_Gal_Thumper',
#    '@BadDudesMusic',
#    '@CMPunk',
#    '@Capcom_Unity',
#    '@Cloyster',
#    '@CodingCrow',
#    '@DJPenguin3',
#    '@Dave_Clynick',
#    '@David_Wise',
#    '@Dugtrio',
#    '@Gary_Oak_',
#    '@Harada_TEKKEN',
#    '@IAmArique',
#    '@IMPACTWRESTLING',
#    '@JhonenV',
#    '@JonTronShow',
#    '@JoshuaMorse',
#    '@KeithApicary',
#    '@LogicIsKey',
#    '@Lord_Voldemort7',
#    '@Lost_CapriSun',
#    '@Lucahjin',
#    '@Mustin',
#    '@MyWayEnt',
#    '@Naztradamix',
#    '@Official_PAX',
#    '@PCULL44444',
#    '@ProfOak',
#    '@Proton_Jon',
#    '@RareLtd',
#    '@RealTalkInc',
#    '@SEGA',
#    '@SeeAdri_Shine',
#    '@Sega',
#    '@Shano_Fett',
#    '@Smashfan64',
#    '@SnoopDogg',
#    '@SolarPrimal',
#    '@TMoon72',
#    '@TTP83',
#    '@TheOneUpsBand',
#    '@TheRealBeano',
#    '@Tru_Inferno',
#    '@VICE',
#    '@WWE',
#    '@YouTube',
#    '@_Charizard_',
#    '@_illy__',
#    '@a',
#    '@anosou',
#    '@bbriggsmusic',
#    '@bigggestbitchh',
#    '@brentalfloss',
#    '@chuggaaconroy',
#    '@dannyBstyle',
#    '@egoraptor',
#    '@joceyybby',
#    '@linoone',
#    '@loveCAGO',
#    '@mellogear',
#    '@mrbigchadwick',
#    '@norgans',
#    '@ocremix',
#    '@radiomaru',
#    '@realistwuzhere',
#    '@roxannatroi',
#    '@shanniebabii',
#    '@ssjnaraku',
#    '@star_ambition91',
#    '@supershigi',
#    '@swaggaqueen09',
#    '@thatgamecompany',
#    '@therealbeano',
#    '@youtube'}),
#  ('158419434',
#   {'#',
#    '#1',
#    '#100Greatest',
#    '#10FCQueTemOMeuRespeito',
#    '#10bandsilove',
#    '#20',
#    '#3',
#    '#4',
#    '#4th',
#    '#8YearsWithParamore',
#    '#AgridoceNaBrasa',
#    '#BELIEBERS',
#    '#BestBandInTheWorld',
#    '#BestIcons',
#    '#BestParamoreMoments',
#    '#Capricórnio',
#    '#ChamberofSecrets',
#    '#Coachella',
#    '#Curiosidades',
#    '#DT',
#    '#Daydreaming',
#    '#EuPegaria',
#    '#FATO',
#    '#FF',
#    '#FF\'s"',
#    '#FF\'s,"',
#    '#FKNresponde',
#    '#FP',
#    '#FS',
#    '#FollowNow',
#    '#FreakingOut',
#    '#GiveMeToTheWaves',
#    '#HP2',
#    '#HPWizardsCollection',
#    '#HappyBdayJeremy',
#    '#HarryPotter',
#    '#HayleyPhotoOfTheDay',
#    '#IThankGod',
#    '#IWishYouKnew',
#    '#IfYouKnowMeWell',
#    '#KILLERCOLLABOS',
#    '#LOL',
#    '#Libra',
#    '#MMM',
#    '#MTVFirst',
#    '#MTVr',
#    '#MovieAwards',
#    '#MyHeartToParamore',
#    '#MêsParamore',
#    '#NP',
#    '#NYC',
#    '#NoticiaFALSA',
#    '#Notícia',
#    '#NotíciaFalsa',
#    '#NowPlaying',
#    '#Oscars',
#    '#PRMRCuriosidades',
#    '#PWG',
#    '#ParaFamily',
#    '#ParaFamily?',
#    '#ParaNews',
#    '#Parafamily',
#    '#Paramore',
#    '#ParawhoreThing',
#    '#PeloParamoreEu',
#    '#PremioMultishow2012',
#    '#RT',
#    '#ReplaceParamoreSongsWithChurro',
#    '#SXSW',
#    '#StopChildAbuse',
#    '#StrangeClouds',
#    '#TDKR',
#    '#TVZ',
#    '#TVZBelas',
#    '#ThankYouFriends?',
#    '#TheBattleOfHogwarts',
#    '#TheVoice',
#    '#ThingsIDislike',
#    '#TodoParawhore',
#    '#TreadOnTrafficking',
#    '#Typeythedefinitonofperfection',
#    '#WearYourParamoreShirt',
#    '#WearYourParamoreShirtDay',
#    '#WearYourParamoreShirtDay"',
#    '#WearYourParamoreShirtDay?',
#    '#WordsYouWillNeverHearMeSay',
#    '#aliceinwonderlandride',
#    '#alliwanted',
#    '#beyondfamous',
#    '#bummer',
#    '#butyoudoanyway',
#    '#butyoushouldnttweetthem',
#    '#cantwaittobeinthesunshinewithfriends',
#    '#careful',
#    '#chatiado',
#    '#citing',
#    '#coachella',
#    '#disney',
#    '#familyrocks',
#    '#ff',
#    '#follow',
#    '#foodtweet',
#    '#foodtweets',
#    '#generalghost',
#    '#genghostinterview',
#    '#gettinold.....?',
#    '#hallelujah',
#    '#helpspreadthis',
#    '#ignorance',
#    '#inthemourning',
#    '#itreallydoesfeelsoooogood',
#    '#itsalife',
#    '#justsaying',
#    '#kindofmissedthisfeeling',
#    '#lol',
#    '#loveyouhairyface',
#    '#misheardlyrics',
#    '#mmmbopentrancemusic',
#    '#monster',
#    '#movieawards',
#    '#nofa',
#    '#nothing',
#    '#nottrue',
#    '#nowplaying',
#    '#np',
#    '#ouch',
#    '#parafact',
#    '#parafamily',
#    '#parafamilyfact',
#    '#paramore',
#    '#paramore4thalbum',
#    '#parasluts',
#    '#parastream',
#    '#parawhores',
#    '#polemica',
#    '#pressure',
#    '#shoptillyoudr',
#    '#supercute',
#    '#thanks',
#    '#thatsinsane',
#    '#truestory',
#    '#wearyourparamoreshirtday',
#    '#whendirtyjokesaretooeasy',
#    '#xatiada',
#    '#yo',
#    '@01motherfucker',
#    '@ARTTM',
#    '@AfastoNargules',
#    '@AllTimeLowCat',
#    '@AllWeKnowIsMia',
#    '@AltPress',
#    '@AmericanIdol',
#    '@AmexCD',
#    '@ApologiesDead',
#    '@ArianaGBarrera',
#    '@ArthurSays',
#    '@Avengers',
#    '@AvrilBrasil',
#    '@AvrilLavigne',
#    '@BRFCParamore',
#    '@BRJeremyDavis',
#    '@BRTaylorYork',
#    '@BRyoumeatsix',
#    '@BattleshipMovie',
#    '@BreatheForPmore',
#    '@Breathe_Pmore',
#    '@BrendaYelyah',
#    '@CAPTUrei',
#    '@CDixonAI11',
#    '@CMPunk',
#    '@CaitlinDyess',
#    '@CandyHeartsBand',
#    '@Coachella',
#    '@ComediaParamore',
#    '@CorrinCampbell',
#    '@DAdaphneEE',
#    '@DakotahRae',
#    '@DanFBR',
#    '@EcuParamore',
#    '@Eliza_Coupe',
#    '@Elle_Gore',
#    '@EmWatson',
#    '@EndlesslyPara',
#    '@Ericksonfire',
#    '@EuropeParamore',
#    '@Evy_Lynch',
#    '@FBRWebstore',
#    '@FCAvrilBrazil',
#    '@FCCrushParamore',
#    '@FCParamoreChile',
#    '@FUSETV',
#    '@FansBrParamore',
#    '@FansFrParamore',
#    '@Fans___PaRaMoRe',
#    '@FcoFKNElektra',
#    '@FearlessRecords',
#    '@FightingForPmor',
#    '@Fiuk',
#    '@ForLoveParamore',
#    '@FranceParamore',
#    '@FrasesParamore',
#    '@Fueled',
#    '@FueledByRamen',
#    '@FueledByRamen\'s"',
#    '@Gabi_Robsten',
#    '@GaboRamos',
#    '@GenGhost',
#    '@GenGhost\'s"',
#    '@GenGhost;',
#    '@GenGhostBR',
#    '@GeneralGhostNZ',
#    '@GetYourShovel__',
#    '@GuilleRiot',
#    '@HAYLEYMACUMBERA',
#    '@HPcuriosidades',
#    '@HRC',
#    '@HarryPotterFilm',
#    '@Harry_Styles',
#    '@Haybundinha',
#    '@Haydasdorgas',
#    '@HaylesBall',
#    '@HayleyBRCom',
#    '@HayleyBrasil',
#    '@HayleyFact',
#    '@HayleyFromPmore',
#    '@HayleyMalCriada',
#    '@HayleyMexico',
#    '@HayleyMySmile',
#    '@HayleyOurQueen',
#    '@HayleyPerfeita',
#    '@HayleyPikachu',
#    '@HayleySupport_',
#    '@HayleyWArg',
#    '@HayleyWCO',
#    '@HayleyWOnline',
#    '@HayleyWPoland',
#    '@HayleyWSpain',
#    '@HayleyWUK',
#    '@HayleyWVe',
#    '@HayleyW_BH',
#    '@HayleyW_GR',
#    '@HayleyWfansite',
#    '@HayleyWonline',
#    '@Hayleyllujah',
#    '@Hayleys_Pussy',
#    '@Haymeupicles',
#    '@HechosParamore',
#    '@HotTopic',
#    '@HyroDaHero',
#    '@IanWhiteTattoos',
#    '@IsadoraFolco',
#    '@ItsAHayleyThing',
#    '@ItsFreakPmore',
#    '@JAParamore',
#    '@JLo',
#    '@JOSHSENSUAL',
#    '@JTHlovers',
#    '@JapanParamore',
#    '@JasonPierceDRUM',
#    '@JeremyDArg',
#    '@JeremyDBrasil',
#    '@JeremyDavisARG',
#    '@JeremyDavisVen',
#    '@JeremyPerfeito',
#    '@JeremySeuTotoso',
#    '@JessicaSimpson',
#    '@Jheen_',
#    '@JoaoVgama',
#    '@JoeyRyanOnline',
#    '@JogosVorazesBRA',
#    '@JohanRolwen',
#    '@JonY2K',
#    '@JonY2K\'s"',
#    '@JonY2K;',
#    '@JonY2Kbrazil',
#    '@JonasBrothers',
#    '@JosephandJosep',
#    '@Joshfarro87',
#    '@JssParamore',
#    '@JulianaReplace',
#    '@JustinBieber',
#    '@KROQ',
#    '@KarlaColina_',
#    '@KerrangMagazine',
#    '@KerrangRadio',
#    '@KevinnParamore',
#    '@KillerQueenMCR',
#    '@LETGOdwork',
#    '@LabelGrey',
#    '@LinkinParkVE',
#    '@LiveForHayley',
#    '@LiveForJeremy',
#    '@LivingParamore',
#    '@Love146',
#    '@LuaraaD',
#    '@LuizThunderbird',
#    '@MTV',
#    '@MTV1',
#    '@MTVBrasil',
#    '@MTVBuzzworthy',
#    '@MTVClutch',
#    '@MTVNews',
#    '@MTVRapFix',
#    '@MacumbaParamore',
#    '@MaisQueLovatic',
#    '@MileyCyrus',
#    '@MirandaCosgrove',
#    '@MisguidedGoats',
#    '@Mix_TV',
#    '@Mix_Tv',
#    '@Monsterrawrrr_',
#    '@Mrs_S_Reckless',
#    '@MundialParafans',
#    '@MundialParamore',
#    '@MyCrazyParamore',
#    '@NASA\'s"',
#    '@NBCTheVoice',
#    '@NMEmagazine',
#    '@NZparamore',
#    '@NatTaylorMusi',
#    '@NatTaylorMusic',
#    '@NateHenrysays',
#    '@NewsParamoreBr',
#    '@NextMovie',
#    '@NickiMinaj',
#    '@NickyToons',
#    '@NoticiasPmoreBr',
#    '@OZparamore',
#    '@OnTopTVZ',
#    '@OneBasketCase',
#    '@OnlyParamoore',
#    '@OurNameIsFun',
#    '@PAOCOMPARAMORE',
#    '@PARAMORERUSSIA_',
#    '@PARAMOREandMore',
#    '@POKOPOKOPIKOTAN',
#    '@Pa',
#    '@PanicAtTheDisco',
#    '@Para',
#    '@ParaFamilyFtw',
#    '@ParaFamilyGB',
#    '@ParaLoversBR',
#    '@ParaScots',
#    '@Paraddicts',
#    '@ParafamilyMLA',
#    '@ParafanaticsBR',
#    '@ParafansBrazil',
#    '@Paralovers4ever',
#    '@Paramo',
#    '@Paramor',
#    '@Paramore',
#    '@Paramore4fans',
#    '@ParamoreARG',
#    '@ParamoreARG)',
#    '@ParamoreAus',
#    '@ParamoreAvenue',
#    '@ParamoreBE',
#    '@ParamoreBEWARE',
#    '@ParamoreBRCom',
#    '@ParamoreBraz',
#    '@ParamoreBrazil',
#    '@ParamoreBrazil;',
#    '@ParamoreBritain',
#    '@ParamoreBsB',
#    '@ParamoreCanada',
#    '@ParamoreCity',
#    '@ParamoreColmbia',
#    '@ParamoreCro',
#    '@ParamoreDance',
#    '@ParamoreENG',
#    '@ParamoreEcuador',
#    '@ParamoreEh',
#    '@ParamoreEh\'s"',
#    '@ParamoreEternal',
#    '@ParamoreFB',
#    '@ParamoreFSite',
#    '@ParamoreFact',
#    '@ParamoreFanFact',
#    '@ParamoreFanfics',
#    '@ParamoreGB',
#    '@ParamoreGB_USA',
#    '@ParamoreGlz',
#    '@ParamoreHON',
#    '@ParamoreHouse',
#    '@ParamoreIndia',
#    '@ParamoreIsraelF',
#    '@ParamoreItalian',
#    '@ParamoreJakarta',
#    '@ParamoreKorea',
#    '@ParamoreLand',
#    '@ParamoreLatin',
#    '@ParamoreMX',
#    '@ParamoreMinas',
#    '@ParamoreMyVice',
#    '@ParamoreNordest',
#    '@ParamoreNws',
#    '@ParamoreOurBand',
#    '@ParamoreOurSoul',
#    '@ParamorePeruFC',
#    '@ParamoreSpain',
#    '@ParamoreSpanish',
#    '@ParamoreStoreBR',
#    '@ParamoreStreet',
#    '@ParamoreThai',
#    '@ParamoreTown',
#    '@ParamoreTrueLuv',
#    '@ParamoreUA',
#    '@ParamoreUAI',
#    '@ParamoreUK_IRE',
#    '@ParamoreUK_IRE)',
#    '@ParamoreUnited',
#    '@ParamoreUpdates',
#    '@ParamoreVnzla',
#    '@ParamoreWW',
#    '@ParamoreWebCrew',
#    '@ParamoreWhores',
#    '@Paramore_Chech',
#    '@Paramore_FC_BR',
#    '@Paramore_GR',
#    '@Paramore_Mex',
#    '@Paramore_Panama',
#    '@Paramore_TL',
#    '@Paramoreans',
#    '@Paramoreday',
#    '@Paramorefanclub',
#    '@ParamoreinCR',
#    '@ParamoremyDecoy',
#    '@ParamoresGaga',
#    '@ParamoresUKFans',
#    '@Paramoretags',
#    '@Paramoretop10',
#    '@ParawhoresLA',
#    '@PipocaGold',
#    '@PittyLeone',
#    '@PlantaoMIX',
#    '@PmoreFranklin',
#    '@PmoreOurLives',
#    '@Pollynoble',
#    '@Porraranger',
#    '@Power_Paramore',
#    '@Preds',
#    '@PrettyReckBR',
#    '@RedEarthTrade',
#    '@RickBonadio',
#    '@Rihanna',
#    '@Rihanna\'s"',
#    '@Rodss_cunha',
#    '@SA_Paramore',
#    '@SENTOAVARAEMVCS',
#    '@SPINmagazine',
#    '@SWEparamore',
#    '@SWStheband',
#    '@SamsMochi',
#    '@SamueelMedeiros',
#    '@SeriesTVix',
#    '@SetYourGoals',
#    '@ShadingLimelite',
#    '@SignosFodas',
#    '@SoyFanDParamore',
#    '@SpecialParamore',
#    '@Spotify',
#    '@StephenKeech',
#    '@StephenLooker',
#    '@StevenJBattelle',
#    '@SublimeWithRome',
#    '@SuperParamoreBR',
#    '@TOP10MTV',
#    '@TPRbr',
#    '@TRANSYLV4NIA',
#    '@TRSBRasil',
#    '@TVDBR',
#    '@TayMeuMcDonalds',
#    '@TaylorLunatico',
#    '@TaylorPerfeicao',
#    '@TaylorYo',
#    '@TaylorYonline',
#    '@TaylorYorkArg',
#    '@TaylorYorkFTW',
#    '@TaylorYorkFreak',
#    '@TaylorYorkcombr',
#    '@Tayloryorkperu',
#    '@TeAmoParamore',
#    '@TeamJonHoward',
#    '@TeamOfParamore',
#    '@TeamParangels',
#    '@ThatJeremyDavis',
#    '@The',
#    '@TheBamboozle',
#    '@TheDenison',
#    '@TheHungerGames',
#    '@TheMashaFans',
#    '@TheParaFamily',
#    '@TheParaFans',
#    '@TheParaWorld',
#    '@TheParamoreArmy',
#    '@TheParamoreBand',
#    '@TheParamoreCity',
#    '@TheParamoreCrew',
#    '@TheRealBitter',
#    '@TheSwellers',
#    '@ThomasFiss',
#    '@TotallyParamore',
#    '@Tourmangler',
#    '@Twilight',
#    '@TwittaParamore',
#    '@USParamore',
#    '@VEParamore',
#    '@VH1',
#    '@VampireDoll22',
#    '@VansWarpedTour',
#    '@VemkParamore',
#    '@VersaEmerge',
#    '@ViniSantaela',
#    '@VodkaLavignea',
#    '@Vorterix',
#    '@WLPFansite',
#    '@WarnerMusicBR',
#    '@WeAreParamore',
#    '@WorldS2Paramore',
#    '@XChadballX',
#    '@YMandCharlie',
#    '@Yelyahyall',
#    '@YesParamore',
#    '@YouTube',
#    '@Youaresuchastar',
#    '@YourParamore',
#    '@YourParamoreLA',
#    '@ZacDorgas',
#    '@_1Renegada',
#    '@_MORTANDELA',
#    '@_ParamoreBrasil',
#    '@_zigga',
#    '@a',
#    '@absolutepunk',
#    '@acesso_mtv',
#    '@agridoce',
#    '@aidualkkula',
#    '@alltimelina',
#    '@alyssasproat',
#    '@analueeza',
#    '@andrewsken',
#    '@antoboros',
#    '@awphotographs',
#    '@bandacw7',
#    '@bearibeeiro',
#    '@bestfriendpmore',
#    '@bestycoastyy',
#    '@bestycoastyy\'s"',
#    '@biancariot',
#    '@bianovelli_',
#    '@blingringmovie',
#    '@boanoitelucas',
#    '@bobatl',
#    '@bobatl\'s"',
#    '@br3atheforlove',
#    '@branchesbro',
#    '@bruna_paim',
#    '@bryanbrown',
#    '@calcinhadahay',
#    '@camilafludd',
#    '@cancerbats',
#    '@canonbluemusic',
#    '@carlyraejepsen',
#    '@charlavail',
#    '@checkyesisa',
#    '@chrissc85',
#    '@cissanaweb',
#    '@clandestinerain',
#    '@coldfeijao',
#    '@compadrewash',
#    '@craigowens',
#    '@d_MyHeart',
#    '@dansmithism',
#    '@daorarelogio',
#    '@ddecoy',
#    '@ddlovato',
#    '@diykimmy',
#    '@dmes_bia',
#    '@eblairproject',
#    '@edennlynn',
#    '@effyst0nemm',
#    '@ehshinealight',
#    '@elektrafkn',
#    '@ellieparamore_',
#    '@esponjadahay',
#    '@ethanluck',
#    '@evelinegouveia_',
#    '@fakenumber',
#    '@fbrstreetteam',
#    '@fiuk',
#    '@folieajade',
#    '@franceparamore',
#    '@fresnorock',
#    '@fridayay',
#    '@fuckmeyelyah',
#    '@fueledbyadam',
#    '@fueledbyadamFC',
#    '@fueledbyramen.com',
#    '@funkdoparamore',
#    '@gabesimas',
#    '@gaiapassarelli',
#    '@genghost',
#    '@genghostfans',
#    '@genghostfans;',
#    '@gmail.com',
#    '@gotye',
#    '@hadassa_nery',
#    '@hansonmusic',
#    '@haylesball',
#    '@hayleygatuxa',
#    '@hayleyinmyheart',
#    '@hayleymyperfect',
#    '@hayleyporra',
#    '@hayleys_hair',
#    '@hayleyyelyah23',
#    '@hayllocoldworld',
#    '@heathermcnab',
#    '@hechosyelyah',
#    '@helpspreadthis',
#    '@heyanab',
#    '@heygess',
#    '@heylucss',
#    '@hotmail.com',
#    '@houseofkoalas',
#    '@hunterlmb',
#    '@iTaylorYorkFan',
#    '@iTunesMusic',
#    '@ieroina',
#    '@ingrassado',
#    '@itsbelacastro',
#    '@itskeren_25',
#    '@itsparamoore',
#    '@itstaylaryall',
#    '@itstaylor',
#    '@itstaylorbrasil',
#    '@itstayloryall',
#    '@itstayloryall\'s"',
#    '@jemmapc23',
#    '@jeremydavisfans',
#    '@jeremys_beard',
#    '@jonathankindler',
#    '@jongkookie1',
#    '@jonodiener',
#    '@jordanmesser',
#    '@joshfarro87',
#    '@joshfranderp',
#    '@joshfreese',
#    '@joshmeatsix',
#    '@jrmeadkutless',
#    '@jtimberlake',
#    '@justinbieber',
#    '@justinmj',
#    '@jyplaysguitar',
#    '@kalleluck',
#    '@kastarnino',
#    '@kathryndfans',
#    '@katieramen',
#    '@katyperry',
#    '@kawcalori',
#    '@kelly_clarkson',
#    '@kelseyrictor',
#    '@kittykatdav',
#    '@kylerictor',
#    '@kylerictor;',
#    '@lairalara',
#    '@letrasparamore',
#    '@liaximenes',
#    '@liightmeup',
#    '@liiliics',
#    '@lincuzildo',
#    '@lucasfresno',
#    '@maaare',
#    '@maisparamore',
#    '@mandiesousa',
#    '@manuhwdy',
#    '@markhoppus',
#    '@mashable',
#    '@matheusthierre',
#    '@meninestranha',
#    '@mewithoutYou',
#    '@mindywhite',
#    '@minipant',
#    '@miniyelyah',
#    '@mix_tv',
#    '@mrspushover',
#    '@mtv1',
#    '@mtvbrasil',
#    '@mtveuro',
#    '@mtvnews\'"',
#    '@mundialparamore',
#    '@musicmust14',
#    '@mustbecharlotte',
#    '@nadiniyall',
#    '@nath_augsten',
#    '@nattaylormusic',
#    '@nattaylormusic\'s"',
#    '@nickdiener',
#    '@nicoleatworld',
#    '@nicolebuckley',
#    '@nikolaka',
#    '@nowjustjax',
#    '@nxzerooficial',
#    '@nzparamore',
#    '@oblivi4te',
#    '@officialpfc',
#    '@oielets',
#    '@onedirection',
#    '@ournameisfun',
#    '@owlcity',
#    '@paperroute',
#    '@par',
#    '@para_sixer',
#    '@paracircle',
#    '@parahani',
#    '@parakisses',
#    '@paralovur',
#    '@paramisery',
#    '@paramore',
#    '@paramore\'s"',
#    '@paramoreARG',
#    '@paramoreBE',
#    '@paramoreBEWARE',
#    '@paramoreCL',
#    '@paramoreDomRep',
#    '@paramoreFB',
#    '@paramoreHK',
#    '@paramoreMAS',
#    '@paramorePMA',
#    '@paramore_gt',
#    '@paramore_mex',
#    '@paramore_s2',
#    '@paramore_unico',
#    '@paramorebrasil',
#    '@paramorebrazil',
#    '@paramorebrcom',
#    '@paramorecity',
#    '@paramorecrazy_',
#    '@paramoredogueto',
#    '@paramoreecuador',
#    '@paramoreeh',
#    '@paramorefall',
#    '@paramorefans',
#    '@paramorefb',
#    '@paramoregb',
#    '@paramorehk',
#    '@paramoreidn',
#    '@paramorelatin',
#    '@paramoreloves',
#    '@paramoremas',
#    '@paramorenetnews',
#    '@paramoreperufc',
#    '@paramorespain',
#    '@paramoreunited',
#    '@paramoreupdates',
#    '@parasixergirl',
#    '@parawhoreBRASIL',
#    '@parayelyah23',
#    '@pfvrfelps',
#    '@pinterest',
#    '@pmore_NFG',
#    '@pmorefans',
#    '@pmorestreetcrew',
#    '@porracaio',
#    '@porraparamore',
#    '@pottermore',
#    '@pqpvitu',
#    '@programapanico',
#    '@provaomtv',
#    '@psempreparamore',
#    '@radiomtvr',
#    '@raqueijao',
#    '@realmattwalker',
#    '@redearthtrade',
#    '@replacemusic',
#    '@rickbonadio',
#    '@rihanna',
#    '@rodsnts',
#    '@schzimmydeanie',
#    '@schzimmydeanie\'s"',
#    '@scottheisel',
#    '@semspiracy',
#    '@setyourgoals',
#    '@shadyIV',
#    '@sille_enilorac',
#    '@skankoficial',
#    '@srslybinks',
#    '@statesmusic',
#    '@stephenlooker',
#    '@suchcoldworld',
#    '@suplineyall',
#    '@sweparamore',
#    '@taylormomsen',
#    '@taylornobanho',
#    '@taylorswift13',
#    '@teganandsara',
#    '@theBrandiCyrus',
#    '@the_dan_plan',
#    '@thebestpmore',
#    '@thebrowncoat',
#    '@theparamorecity',
#    '@theparaworld',
#    '@titimuller',
#    '@tweesles',
#    '@twentyonepilots',
#    '@twentyonepilots?',
#    '@umrenegado',
#    '@userporra',
#    '@vailafadepmore',
#    '@vcspnc',
#    '@veparamore',
#    '@vicioemparamore',
#    '@warnermusicmex',
#    '@weareparamorepe',
#    '@xHayleyArmy',
#    '@xRawrAndStuff',
#    '@xfifa',
#    '@xryanrussellx',
#    '@xxxxmorgana',
#    '@yeahwilliams',
#    '@yelyahParaRiot',
#    '@yelyahbrasil',
#    '@yelyahbrasil?',
#    '@yelyahcitou',
#    '@yelyahwilliams',
#    '@yelyahwilliams\'"',
#    '@yourparamorela',
#    '@youtube',
#    '@zacfarro'}),
#  ('100318079',
#   {'#',
#    '#1',
#    '#10bandsilove',
#    '#2',
#    '#20',
#    '#24',
#    '#3',
#    '#4',
#    '#4th',
#    '#77',
#    '#AgridoceNaBrasa',
#    '#Believe',
#    '#BestBandInTheWorld',
#    '#BestParamoreMoments',
#    '#CiteUmaGalinha',
#    '#DT',
#    '#Daydreaming',
#    '#EPIC',
#    '#EuPegaria',
#    '#Evanescence',
#    '#FATO',
#    '#FF',
#    '#FF\'s,"',
#    '#FF\'s."',
#    '#FKNResponde',
#    '#FKNresponde',
#    '#FN',
#    '#FP',
#    '#FS',
#    '#GO',
#    '#GoodThingsInTheWorld',
#    '#H',
#    '#HappyBdayJeremy',
#    '#HappyBirthdayHayleyWilliams',
#    '#HayleyPhotoOfTheDay',
#    '#IThankGod',
#    '#IWishYouKnew',
#    '#IfYouKnowMeWell',
#    '#InTheMourning',
#    '#JeremyPicOfTheDay',
#    '#KILLERCOLLABOS',
#    '#KONY2012',
#    '#Libra',
#    '#LollaNoMultishow',
#    '#Love146',
#    '#MMM',
#    '#MTVWorldStage',
#    '#MTVr',
#    '#MileyFacts',
#    '#MovieAwards',
#    '#MyHeartToParamore',
#    '#NP',
#    '#News',
#    '#NoticiaFALSA',
#    '#Notícia',
#    '#PWG',
#    '#ParaFamily',
#    '#ParaMarathon',
#    '#Parafamily',
#    '#Paramore',
#    '#ParamoreFact',
#    '#Parawhores',
#    '#PeloParamoreEu',
#    '#PremioMultishow2012',
#    '#ProvaoMTV',
#    '#RT',
#    '#ReplaceParamoreSongsWithChurro',
#    '#RhapSession',
#    '#STOPSOPA',
#    '#StopChildAbuse',
#    '#StrangeClouds',
#    '#TVZAlbuns',
#    '#TVZBandas',
#    '#TVZBelas',
#    '#TVZBelos',
#    '#TaylorYorkBrasil',
#    '#TheVoice',
#    '#TodoParawhore',
#    '#TreadOnTrafficking',
#    '#WeLoveParamore',
#    '#WearYourParamoreShirt',
#    '#WearYourParamoreShirtDay',
#    '#WearYourParamoreShirtDay?',
#    '#aliceinwonderlandride',
#    '#awesome',
#    '#awkward',
#    '#butyoudoanyway',
#    '#butyoushouldnttweetthem',
#    '#careful',
#    '#chatiada',
#    '#coachella',
#    '#disney',
#    '#excepttweetparamore',
#    '#familyrocks',
#    '#ff',
#    '#ff\'s"',
#    '#follow',
#    '#foodtweet',
#    '#foodtweets',
#    '#gettinold.....?',
#    '#goodnighhht',
#    '#hallelujah',
#    '#hayleywilliams',
#    '#heartbeats',
#    '#helpspreadthis',
#    '#itreallydoesfeelsoooogood',
#    '#itsalife',
#    '#itsaparawhorething',
#    '#jeremydavis',
#    '#jerms',
#    '#justsayin',
#    '#justsaying',
#    '#kindofmissedthisfeeling',
#    '#kony2012',
#    '#lol',
#    '#marryme',
#    '#mmmbopentrancemusic',
#    '#nofa',
#    '#nottrue',
#    '#nowplaying',
#    '#np',
#    '#online',
#    '#ouch',
#    '#parafact',
#    '#parafamily',
#    '#paralove',
#    '#paramore',
#    '#paramore4thalbum',
#    '#parastream',
#    '#parawhores',
#    '#playinggod',
#    '#proud',
#    '#shoptillyoudr',
#    '#shoutout',
#    '#soexcited',
#    '#supercute',
#    '#teamwedonothing',
#    '#theonlyexception',
#    '#truestory',
#    '#wearyourparamoreshirtday',
#    '#whendirtyjokesaretooeasy',
#    '#xatiada',
#    '#yo',
#    '@',
#    '@1013KDWB',
#    '@1035KISSFM',
#    '@146ParamorePH',
#    '@19ester',
#    '@1DcomBR',
#    '@8bitszombiee',
#    '@ARTTM',
#    '@AWKIFalbum',
#    '@ActivateKillsBr',
#    '@AfastoNargules',
#    '@AllWeKnowIsMia',
#    '@Alt3Paramore',
#    '@AltPress',
#    '@AmandaSeyfBR',
#    '@AmericanIdol',
#    '@AmexCD',
#    '@AmyLeeEV',
#    '@Amy_Leebrasil',
#    '@AnaRojasOk',
#    '@AnthonyRaneri',
#    '@Anto_Daniele',
#    '@ApologiesDead',
#    '@ArthurSays',
#    '@AutoLoveBR',
#    '@AvrilBrasil',
#    '@AvrilLavigne',
#    '@BRJeremyDavis',
#    '@BRMileyRayCyrus',
#    '@BRTaylorYork',
#    '@BandaDooelo',
#    '@Betinha_Felipe',
#    '@Bewareofyow',
#    '@BewereOfYou',
#    '@BrandonLarryzz',
#    '@BreatheBrasil',
#    '@BreatheForPmore',
#    '@Breathe_Pmore',
#    '@CANparamore',
#    '@CMPunk',
#    '@CaitlinChaden',
#    '@CaitlinDyess',
#    '@CandyHeartsBand',
#    '@CarolayneP',
#    '@Celmyparamore',
#    '@Circo_Voador',
#    '@Coachella',
#    '@ConexaoSP_BR',
#    '@ConnectParamore',
#    '@CynicalCyanide',
#    '@DAdaphneEE',
#    '@Dakky',
#    '@DakotahRae',
#    '@DakotahRaeFans',
#    '@DanRadcliffeBr',
#    '@DiannaAgron',
#    '@DrewBarrymoreBr',
#    '@ECashman',
#    '@EcuParamore',
#    '@Elle_Gore',
#    '@EmmaWatsonBr',
#    '@EndlesslyPara',
#    '@ErikkeCaixao',
#    '@Espaço',
#    '@EuropeParamore',
#    '@Evan__Heart',
#    '@Evanescence',
#    '@EvannaLBrasil',
#    '@FBRWebstore',
#    '@FCCrushParamore',
#    '@FCParamoreChile',
#    '@FC_brParamore',
#    '@FKNnumbers',
#    '@FUSETV',
#    '@FakenumberSemfr',
#    '@FanParamoree',
#    '@FansBrParamore',
#    '@FansFrParamore',
#    '@FcoFKNElektra',
#    '@FightingForPmor',
#    '@ForLoveParamore',
#    '@FranceParamore',
#    '@FueledByRamen',
#    '@FueledByRamen\'s"',
#    '@FueledByRamenAR',
#    '@Gabi_Robsten',
#    '@GenGhost',
#    '@GetYourShovel__',
#    '@Gliterdademi',
#    '@GuilleRiot',
#    '@GwynethBrasil',
#    '@HAYLEYSENSUAL',
#    '@HCWParamore',
#    '@HRC',
#    '@HSBC',
#    '@HWHeadbangers',
#    '@Ha',
#    '@Hay',
#    '@Haybundinha',
#    '@Haydasdorgas',
#    '@HaylesSpongeBob',
#    '@HayleyBRCom',
#    '@HayleyBrasil',
#    '@HayleyFact',
#    '@HayleyFromPmore',
#    '@HayleyIronica',
#    '@HayleyMaluka',
#    '@HayleyMexico',
#    '@HayleyMySmile',
#    '@HayleyNWArgOn',
#    '@HayleyPerfeicao',
#    '@HayleyPerfeita',
#    '@HayleyPlanet',
#    '@HayleyWAddict',
#    '@HayleyWArg',
#    '@HayleyWCO',
#    '@HayleyWFanss',
#    '@HayleyWFin',
#    '@HayleyWFreaks',
#    '@HayleyWOnline',
#    '@HayleyWPoland',
#    '@HayleyWSpain',
#    '@HayleyWUK',
#    '@HayleyWUruguay',
#    '@HayleyWVe',
#    '@HayleyW_BH',
#    '@HayleyW_GR',
#    '@HayleyWfansite',
#    '@HayleyWonline',
#    '@HayleyWorldFans',
#    '@Hayley_Riiot',
#    '@Hayleys_Pussy',
#    '@HayspiroPmore',
#    '@HechosParamore',
#    '@HeyItsRii',
#    '@HotTopic',
#    '@ILoveElektra',
#    '@ISS_BR',
#    '@IShipCraigity',
#    '@InfosFakeNumber',
#    '@IsadoraFolco',
#    '@ItsAHayleyThing',
#    '@JAParamore',
#    '@JBoficialBR',
#    '@JOSHSENSUAL',
#    '@Jamiefollese',
#    '@JasonPierceDRUM',
#    '@JeremyDArg',
#    '@JeremyDBrasil',
#    '@JeremyDavisARG',
#    '@JeremyDavisVen',
#    '@JessieJ',
#    '@JessieJBrFans',
#    '@JesusYorkM',
#    '@Jheen_',
#    '@JoeDreamBrasil',
#    '@JoeyRyanOnline',
#    '@JogosVorazesBRA',
#    '@JohanRolwen',
#    '@JonY2K',
#    '@Joshliciouss',
#    '@JustRenegade',
#    '@KROQ',
#    '@KatGraham',
#    '@Katichu19',
#    '@KeepCalmNathany',
#    '@KeithFollese',
#    '@KerrangMagazine',
#    '@KillerQueenMCR',
#    '@LETGOdwork',
#    '@LINGUADOJEREMY',
#    '@LadySTparamore',
#    '@LeeTiemi_',
#    '@Liiz_Dawid',
#    '@LindseyByrnes',
#    '@LiveForHayley',
#    '@LiveForJeremy',
#    '@LiviaDelunardo',
#    '@LivingParamore',
#    '@Love146',
#    '@LuAlone',
#    '@LuaraaD',
#    '@LuizThunderbird',
#    '@LunchAtLorellis',
#    '@MGFBR',
#    '@MTV',
#    '@MTV1',
#    '@MTVBrasil',
#    '@MTVBuzzworthy',
#    '@MTVNews',
#    '@MariMoon',
#    '@Milee_Paralover',
#    '@MileyBRcom',
#    '@MirandaCitou',
#    '@MirandaCosgrove',
#    '@MirandaMyLife',
#    '@Miranda_Brasil',
#    '@MisguidedGoats',
#    '@Mix_TV',
#    '@Mix_Tv',
#    '@Monsterrawrrr_',
#    '@Mrs_S_Reckless',
#    '@MundialParafans',
#    '@MundialParamore',
#    '@MyCrazyParamore',
#    '@NBCTheVoice',
#    '@NMEmagazine',
#    '@NZparamore',
#    '@NZparamoreFans',
#    '@NatTaylorMusic',
#    '@NavyParawhore',
#    '@NewsParamoreBr',
#    '@NiallOfficial',
#    '@NickiMinaj',
#    '@NoticiasPmoreBr',
#    '@NowNowFans',
#    '@OZparamore',
#    '@O_ProfetaDiario',
#    '@OhJessieJCom',
#    '@OhJessieJcom',
#    '@OhSelCom',
#    '@OnTopTVZ',
#    '@OneRepublic',
#    '@OurNameIsFun',
#    '@P',
#    '@PAOCOMPARAMORE',
#    '@PARAMORE',
#    '@PARAMORERUSSIA_',
#    '@PARAMOREandMore',
#    '@PMRonlyexceptio',
#    '@POPLine',
#    '@Pa',
#    '@Panetoni',
#    '@PanicAtTheDisco',
#    '@Par',
#    '@Para',
#    '@ParaConfessions',
#    '@ParaDdraigo',
#    '@ParaFamilyFtw',
#    '@ParaFamilyGB',
#    '@ParaIndoMore',
#    '@ParaScots',
#    '@Para_morelovers',
#    '@Paraddicts',
#    '@ParafamiIy',
#    '@ParafamilyMLA',
#    '@ParafansPH',
#    '@Paralovers4ever',
#    '@Paramo',
#    '@Paramore',
#    '@Paramore24h',
#    '@Paramore4album',
#    '@Paramore4fans',
#    '@Paramore?',
#    '@ParamoreAmerica',
#    '@ParamoreAsian',
#    '@ParamoreAus',
#    '@ParamoreAvenue',
#    '@ParamoreBE',
#    '@ParamoreBEWARE',
#    '@ParamoreBRCom',
#    '@ParamoreBrazil',
#    '@ParamoreBritain',
#    '@ParamoreCPT',
#    '@ParamoreCanada',
#    '@ParamoreCity',
#    '@ParamoreColmbia',
#    '@ParamoreCro',
#    '@ParamoreCrowd',
#    '@ParamoreDance',
#    '@ParamoreENG',
#    '@ParamoreEcua',
#    '@ParamoreEcuador',
#    '@ParamoreEh',
#    '@ParamoreEh\'s"',
#    '@ParamoreEternal',
#    '@ParamoreFB',
#    '@ParamoreFSite',
#    '@ParamoreFact',
#    '@ParamoreFanFact',
#    '@ParamoreFans_1',
#    '@ParamoreGB',
#    '@ParamoreGB_USA',
#    '@ParamoreGT',
#    '@ParamoreGlz',
#    '@ParamoreHON',
#    '@ParamoreHouse',
#    '@ParamoreIndia',
#    '@ParamoreIsrael',
#    '@ParamoreIsraelF',
#    '@ParamoreJakarta',
#    '@ParamoreKorea',
#    '@ParamoreLand',
#    '@ParamoreLatam',
#    '@ParamoreLatin',
#    '@ParamoreMKS',
#    '@ParamoreMX',
#    '@ParamoreMendoza',
#    '@ParamoreMinas',
#    '@ParamoreMyVice',
#    '@ParamoreNws',
#    '@ParamoreOurBand',
#    '@ParamoreOurSoul',
#    '@ParamorePeruFC',
#    '@ParamoreS',
#    '@ParamoreSEA',
#    '@ParamoreSK',
#    '@ParamoreSerbia',
#    '@ParamoreSpain',
#    '@ParamoreSpanish',
#    '@ParamoreStreet',
#    '@ParamoreTNG',
#    '@ParamoreThai',
#    '@ParamoreTown',
#    '@ParamoreTrueLuv',
#    '@ParamoreUA',
#    '@ParamoreUK_IRE',
#    '@ParamoreUnited',
#    '@ParamoreUpdates',
#    '@ParamoreVnzla',
#    '@ParamoreWW',
#    '@ParamoreWebCrew',
#    '@ParamoreWhores',
#    '@Paramore_FC_BR',
#    '@Paramore_FF',
#    '@Paramore_FansUK',
#    '@Paramore_GR',
#    '@Paramore_Mex',
#    '@Paramore_Panama',
#    '@Paramore_Spain',
#    '@Paramore_TL',
#    '@Paramoreans',
#    '@Paramoreday',
#    '@ParamoreeFans',
#    '@Paramorefanclub',
#    '@Paramorefansde',
#    '@Paramorehn',
#    '@ParamoreinCR',
#    '@ParamoresGaga',
#    '@ParamoresUKFans',
#    '@Paramoretags',
#    '@ParawhoreFreaks',
#    '@ParawhoreOn',
#    '@ParawhoresLA',
#    '@Parayeahyeah',
#    '@ParmoreTribute',
#    '@Pepsi_Para_Punk',
#    '@PittyLeone',
#    '@PixieLottBr',
#    '@PlantaoMIX',
#    '@PlayGodParamore',
#    '@PlayingParamore',
#    '@PmoreOurLives',
#    '@Pollynoble',
#    '@Porraranger',
#    '@PortalEntreTeen',
#    '@PortalKatyPerry',
#    '@PortalParamore',
#    '@PortalWatic',
#    '@PrettyReckBR',
#    '@ProfitEventos',
#    '@ProudOfPmore',
#    '@PudimDoParamore',
#    '@Rancore',
#    '@RevistaClips)',
#    '@Rihanna\'s"',
#    '@RitaOra',
#    '@Rodss_cunha',
#    '@SA_Paramore',
#    '@SPINmagazine',
#    '@SWEparamore',
#    '@SWStheband',
#    '@SamsMochi',
#    '@SamueelMedeiros',
#    '@SetYourGoals',
#    '@ShadingLimelite',
#    '@SignosFodas',
#    '@Silje1995',
#    '@Sintiatrias',
#    '@SiteKeshaBrasil',
#    '@SiteMegaTeen',
#    '@SleepingWithAlf',
#    '@SomeGuy747',
#    '@SonyMusic',
#    '@SoyFanDParamore',
#    '@SpecialParamore',
#    '@SrtaSyn',
#    '@StephenLooker',
#    '@StevenJBattelle',
#    '@SublimeWithRome',
#    '@SucrilhosDaHay',
#    '@SuperParamoreBR',
#    '@TMJovemBR',
#    '@TOP10MTV',
#    '@TPRbr',
#    '@TRSBRasil',
#    '@TayMeuMcDonalds',
#    '@TaylorLunatico',
#    '@TaylorPerfeicao',
#    '@TaylorYARG',
#    '@TaylorYo',
#    '@TaylorYonline',
#    '@TaylorYorkArg',
#    '@TaylorYorkFTW',
#    '@TaylorYorkFanz',
#    '@TaylorYorkFreak',
#    '@TaylorYorkVE',
#    '@TaylorYorkcombr',
#    '@TeAmoParamore',
#    '@TeamHWilliams',
#    '@TeamOfParamore',
#    '@TeamParangels',
#    '@ThatJeremyDavis',
#    '@TheBamboozle',
#    '@TheEllenShow',
#    '@TheMashaFans',
#    '@TheParaFamily',
#    '@TheParaFamilyBR',
#    '@TheParaFans',
#    '@TheParaWorld',
#    '@TheParamoreArmy',
#    '@TheParamoreBand',
#    '@TheParamoreCity',
#    '@TheParamoreCrew',
#    '@TheReadySetBR',
#    '@TheRock',
#    '@TheSwellers',
#    '@Thuan_Mota',
#    '@Tim_McCord',
#    '@TomFeltonBrasil',
#    '@TotallyParamore',
#    '@Tourmangler',
#    '@True_Parawhore',
#    '@TwittaParamore',
#    '@UKParamore',
#    '@USParamore',
#    '@USparamoreUK',
#    '@UmAnjinhoDoMal',
#    '@UmaDoseDoRock',
#    '@VEParamore',
#    '@VansWarpedTour',
#    '@VersaEmerge',
#    '@VersaEmergeBR',
#    '@ViniSantaela',
#    '@Vorterix',
#    '@WATICBR',
#    '@WLPFansite',
#    '@WakeUpBrazil2',
#    '@WarnerMusicBR',
#    '@WazzupHayley',
#    '@WeAreParamore',
#    '@WeAreParamour',
#    '@WeLoveParamore',
#    '@WeavingTheFate',
#    '@WeavingTheFate-',
#    '@WhatAboutMarcos',
#    '@WorldOfParamore',
#    '@XChadballX',
#    '@Yelyahyall',
#    '@YouTube',
#    '@YourParamore',
#    '@YourParamoreLA',
#    '@ZacDorgas',
#    '@_ParamoreBrasil',
#    '@_justparamore',
#    '@a',
#    '@absolutepunk',
#    '@acesso_mtv',
#    '@adnamaventura',
#    '@afreakparawhore',
#    '@aidualkkula',
#    '@aleksandrapmore',
#    '@aliados',
#    '@allWeknowIsilly',
#    '@alltimelowbr',
#    '@alwaysmusicinme',
#    '@anacronico92',
#    '@andremttr',
#    '@andrewsken',
#    '@antifrase',
#    '@antoboros',
#    '@ashleyarrison',
#    '@atrevida',
#    '@awphotographs',
#    '@bandacine',
#    '@bearibeeiro',
#    '@benbarnes_br',
#    '@bestfriendpmore',
#    '@bestycoastyy',
#    '@bestycoastyy\'s"',
#    '@biaacaardoso_',
#    '@biancariot',
#    '@bieberfbrasil',
#    '@boanoitelucas',
#    '@bobatl',
#    '@bobatl\'s"',
#    '@bobatl)',
#    '@br3atheforlove',
#    '@branchesbro',
#    '@brendahaf',
#    '@cancerbats',
#    '@causeusmile',
#    '@chapnandezfans',
#    '@charlavail',
#    '@checkyesisa',
#    '@chloprentice',
#    '@chrissc85',
#    '@clandestinerain',
#    '@clarisribeiro',
#    '@craigowens',
#    '@cthaiseyall',
#    '@cumback2me',
#    '@dansmithism',
#    '@daorarelogio',
#    '@ddlovato',
#    '@demibrasil',
#    '@desanuvio',
#    '@diykimmy',
#    '@eblemarpires',
#    '@eduardamello',
#    '@ehshinealight',
#    '@elektrafkn',
#    '@ellieparamore_',
#    '@ethanluck',
#    '@evanescence',
#    '@evelinegouveia_',
#    '@everpotter',
#    '@evfandadepre',
#    '@fakenumber',
#    '@fbrstreetteam',
#    '@federicodevito',
#    '@fiuk',
#    '@followfridaytop',
#    '@fridayay',
#    '@fuckmeyelyah',
#    '@fueledbyadam',
#    '@fueledbyramen',
#    '@fueledbyramen.com',
#    '@funkdoparamore',
#    '@gabesimas',
#    '@gabesimas)',
#    '@gaiapassarelli',
#    '@girlsHBO',
#    '@gloriarock',
#    '@gmail.com',
#    '@haydenlamb',
#    '@hayleybr.com',
#    '@hayleydeMel',
#    '@hayleyinmyheart',
#    '@hayleyismyhero',
#    '@hayleymyperfect',
#    '@hayleynwargon',
#    '@hayleyporra',
#    '@hayleyretardada',
#    '@hayleys_hair',
#    '@hayleyyelyah23',
#    '@hayllocoldworld',
#    '@heathermcnab',
#    '@hechosyelyah',
#    '@helloc0ldworld_',
#    '@helpspreadthis',
#    '@heygess',
#    '@heyjullie',
#    '@heylucss',
#    '@hotmail.com',
#    '@houseofkoalas',
#    '@hunterlmb',
#    '@iDavidRivas',
#    '@iJoseMora',
#    '@iTaylorYorkFan',
#    '@iTunesMusic',
#    '@icarly4637',
#    '@ikeara',
#    '@ikkinsnommis',
#    '@ingrassado',
#    '@irabrianmiller',
#    '@itsEvandro',
#    '@itsangeyall',
#    '@itsbelacastro',
#    '@itsjujisyall',
#    '@itskeren_25',
#    '@itslucasyall',
#    '@itsparamoore',
#    '@itstaylaryall',
#    '@itstaylorbrasil',
#    '@itstayloryall',
#    '@itstayloryall\'s"',
#    '@jbrazilofficial',
#    '@jemmapc23',
#    '@jennathecat',
#    '@jennlawrencebr',
#    '@jeremydavisfans',
#    '@jeremys_beard',
#    '@jongkookie1',
#    '@jonodiener',
#    '@jorcalori',
#    '@joshfranderp',
#    '@joshmeatsix',
#    '@justinbieber',
#    '@justinmj',
#    '@jyplaysguitar',
#    '@kastarnino',
#    '@kathryndfans',
#    '@katyperry',
#    '@kawcalori',
#    '@kerlibrasilnet',
#    '@kittykatcam',
#    '@kittykatdav',
#    '@ladygaga',
#    '@leaparapapara',
#    '@lenadunham”',
#    '@letrasparamore',
#    '@linkinpark',
#    '@linneadaily',
#    '@livelybr',
#    '@livingparamore',
#    '@lojacdbrasil',
#    '@lucy_lacrymosa',
#    '@maaare',
#    '@maisa9841',
#    '@maisparamore',
#    '@mandiesousa',
#    '@matheusthierre',
#    '@mcosgrovecombr',
#    '@mcrawesome001',
#    '@mewithoutYou',
#    '@mewithparamore',
#    '@michele_its',
#    '@midiorama',
#    '@mindywhite',
#    '@miniyelyah',
#    '@mishacollins',
#    '@mix_tv',
#    '@moveslikebrubs',
#    '@mtv',
#    '@mtv1',
#    '@mtvbrasil',
#    '@mtveuro',
#    '@mtvnews\'"',
#    '@mundialparamore',
#    '@muse_venezuela',
#    '@mushroombeast',
#    '@musicmust14',
#    '@mustbecharlotte',
#    '@nacaodamusica',
#    '@natasa_t',
#    '@nicolebuckley',
#    '@nowjustjax',
#    '@nxzerooficial',
#    '@onedirection',
#    '@onedirectionBR',
#    '@ournameisfun',
#    '@ozparavancrew',
#    '@par',
#    '@paracircle',
#    '@parahani',
#    '@paralovur',
#    '@param',
#    '@paramisery',
#    '@paramonsters',
#    '@paramore',
#    '@paramore\'s"',
#    '@paramore)',
#    '@paramore?',
#    '@paramoreARG',
#    '@paramoreBEWARE',
#    '@paramoreBH',
#    '@paramoreCL',
#    '@paramoreDo',
#    '@paramoreDomRep',
#    '@paramoreHK',
#    '@paramoreMAS',
#    '@paramoreMKS',
#    '@paramorePMA',
#    '@paramorePT',
#    '@paramore_unico',
#    '@paramorearg',
#    '@paramorebg',
#    '@paramorebrasil',
#    '@paramorebrazil',
#    '@paramorebrcom',
#    '@paramorecity',
#    '@paramorecl',
#    '@paramorecolmbia',
#    '@paramoreecuador',
#    '@paramoreeh',
#    '@paramorefans',
#    '@paramoregb',
#    '@paramoregermany',
#    '@paramorehk',
#    '@paramoreidn',
#    '@paramoreireland',
#    '@paramorejokes',
#    '@paramorelatino',
#    '@paramoreloves',
#    '@paramoremusicom',
#    '@paramorenetnews',
#    '@paramorepl',
#    '@paramoresfans',
#    '@paramoresg',
#    '@paramorespain',
#    '@paramoretown',
#    '@paramoreuru',
#    '@paramorewebcrew',
#    '@paramusics',
#    '@parasixergirl',
#    '@parawhoreBRASIL',
#    '@pinguimfkn',
#    '@pmore_NFG',
#    '@pmorestreetcrew',
#    '@pnnworldnews',
#    '@poopclub',
#    '@portallovato',
#    '@pqpjensen',
#    '@pqpvitu',
#    '@provaomtv',
#    '@provaomtv?',
#    '@psempreparamore',
#    '@radiomtvr',
#    '@rdgzantonio',
#    '@reIoisa',
#    '@realmattwalker',
#    '@riandawson',
#    '@rickbonadio',
#    '@rihanna',
#    '@rodsnts',
#    '@rustyasahalo',
#    '@s',
#    '@schzimmydeanie',
#    '@schzimmydeanie\'s"',
#    '@scottheisel',
#    '@semspiracy',
#    '@seriespara',
#    '@setyourgoals',
#    '@shadyIV',
#    '@shak74',
#    '@spin1038',
#    '@srreckless',
#    '@statesmusic',
#    '@stephenlooker',
#    '@suchcoldworld',
#    '@suplineyall',
#    '@taylormomsen',
#    '@taylorswift13',
#    '@teganandsara',
#    '@theBrandiCyrus',
#    '@the_dan_plan',
#    '@thebestpmore',
#    '@thebrowncoat',
#    '@thomascalmeida',
#    '@titimuller',
#    '@tweesles',
#    '@twentyonepilots',
#    '@twentyonepilots?',
#    '@twittpotter',
#    '@ua_nda',
#    '@umrenegado',
#    '@unfocusedd',
#    '@usatoday',
#    '@vailafadepmore',
#    '@veparamore',
#    '@vinsttt',
#    '@vitsays',
#    '@vvnikky',
#    '@warnermusicbr',
#    '@weareparamorepe',
#    '@webrockers',
#    '@wen0511',
#    '@xHayleyArmy',
#    '@xRawrAndStuff',
#    '@xryanrussellx',
#    '@xyeahtony',
#    '@yealuiza',
#    '@yelyahWMexico',
#    '@yelyah_quotes',
#    '@yelyahbrasil',
#    '@yelyahbrasil?',
#    '@yelyahcitou',
#    '@yelyahwilliams',
#    '@yelyahwilliams\'"',
#    '@youDematsix',
#    '@youtube',
#    '@zac_brasil',
#    '@zacfarro',
#    '@zaynmalik',
#    '@zumbiperdido'}),
#  ('262310943',
#   {'#AreYouSerious',
#    '#Axxess',
#    '#BeatTheClock',
#    '#BestInTheWorld',
#    '#ByeByeBellas',
#    '#CultOfPersonality',
#    '#DearWWEBoard',
#    '#Divas',
#    '#ExtremeRules',
#    '#Funkasaurus',
#    '#HellinaCell',
#    '#ItsClobberinTime',
#    '#Miami',
#    '#MondayNightRawStarringBrockLesnar',
#    '#NXT',
#    '#NameTheChamps',
#    '#OverTheLimit',
#    '#PeoplePower',
#    '#RAW',
#    '#RatedRSuperstar',
#    '#Raw',
#    '#Raw?',
#    '#Santino',
#    '#SmackDown',
#    '#SomebodyCallMyMomma',
#    '#SuperShow',
#    '#SuperShow?',
#    '#SuperSmackDown',
#    '#Superstar',
#    '#TT',
#    '#TeamBringIt',
#    '#TeamJohnny',
#    '#TeamTeddy',
#    '#ThankYouEdge',
#    '#TheViper',
#    '#TimeToPlayTheGame',
#    '#TripleH',
#    '#WM28',
#    '#WWE',
#    '#WWECoverBands',
#    '#WWEHOF',
#    '#WrestleMania',
#    '#YES',
#    '#YesYesYes',
#    '#beastar',
#    '#on@iTunesMusic',
#    '#raw',
#    '#wrestlemania',
#    '#wwe',
#    '@AliciaFoxy',
#    '@BrodusClay',
#    '@CMPunk',
#    '@CodyRhodesWWE',
#    '@DavidOtunga',
#    '@DavidOtunga\'s"',
#    '@DerrickWWE',
#    '@EveMarieTorres',
#    '@GetGlue',
#    '@GreatestMatches',
#    '@HEELZiggler',
#    '@HEELZiggler\'s"',
#    '@HeathSlaterOMRB\'s"',
#    '@HowardFinkel',
#    '@IAmJericho',
#    '@JoeyStyles',
#    '@JohnCena',
#    '@JohnCena\'s"',
#    '@JohnnyWWE',
#    '@Justin__Gabriel',
#    '@KeithApicary',
#    '@KiddWWE',
#    '@MayorBillFinch',
#    '@MikeTheMiz',
#    '@MikeTheMiz\'s"',
#    '@MilanMiracle',
#    '@NatByNature',
#    '@NatbyNature',
#    '@RAINN01',
#    '@RandyOrton',
#    '@RandyOrton\'s"',
#    '@RealJackSwagger',
#    '@RealKellyKelly',
#    '@ReyMysterio',
#    '@RonKillings',
#    '@TheBellaTwins',
#    '@TheBellaTwins\'"',
#    '@TheBethPhoenix',
#    '@TheCurtHawkins',
#    '@TheMarkHenry',
#    '@TheRock',
#    '@TitusNXT',
#    '@TrueKofi',
#    '@TrueKofi\'s"',
#    '@USA_Network',
#    '@WNWOTV',
#    '@WWE',
#    '@WWE\'s"',
#    '@WWEAYS',
#    '@WWEDanielBryan',
#    '@WWEEpico',
#    '@WWEHornswoggle',
#    '@WWEJoshMathews',
#    '@WWEMusic',
#    '@WWERawGM',
#    '@WWERoadDogg',
#    '@WWESheamus',
#    '@WWEShop',
#    '@WWETheBigShow',
#    '@WWETheBigShow\'s"',
#    '@WWEUniverse',
#    '@WWLP22News',
#    '@WadeBarrett',
#    '@WrestleMania',
#    '@YouTube',
#    '@ZackRyder',
#    '@beaSTAR2011',
#    '@beaSTARalliance',
#    '@beastaralliance',
#    '@getglue',
#    '@iTunesMusic',
#    '@miamiherald',
#    '@mikethemiz',
#    '@milanmiracle',
#    '@reymysterio',
#    '@rrwwe',
#    '@thebellatwins',
#    '@wwe',
#    '@wwejoshmathews'}),
#  ('9855382',
#   {'#Afghanistan',
#    '#Budget',
#    '#GSA',
#    '#Gov20',
#    '#HR3261',
#    '#OCv3',
#    '#OnThisDay',
#    '#OpenData',
#    '#S1925',
#    '#SConRes43',
#    '#SOPA',
#    '#Senate',
#    '#Syria',
#    '#THOMASlive',
#    '#VAWA',
#    '#WHCD',
#    '#gov20',
#    '#opengov',
#    '@LawLibCongress',
#    '@NASA',
#    '@OversightDems',
#    '@RepPaulRyan',
#    '@SenGOP_Floor',
#    '@SpeakerBoehner',
#    '@SteveForbesCEO',
#    '@THOMASdotgov',
#    '@Tout',
#    '@USGSA)',
#    '@cspan',
#    '@cspanwj',
#    '@govtrack',
#    '@librarycongress',
#    '@nielslesniewski',
#    '@ppolitics'}),
#  ('11928542',
#   {'#1',
#    '#ECGC',
#    '#PAX',
#    '#sworcery',
#    '@%&\'s"',
#    '@AndrewNK',
#    '@BenKuchera',
#    '@BenPerLee',
#    '@Bunnyspatial',
#    '@Carachan1',
#    '@DCDeacon',
#    '@DavidEllis',
#    '@EvNarc',
#    '@EvolveTom',
#    '@GordonVanDyke',
#    '@Hawk_SE',
#    '@Instig8iveJourn',
#    '@JamesStevenson',
#    '@JustinMcElroy',
#    '@KCoxDC',
#    '@Kotaku',
#    '@KyleOrl',
#    '@LightAesthetic',
#    '@LukePlunkett',
#    '@Marc_Normandin',
#    '@MikeMcWhertor',
#    '@MrWasteland',
#    '@OHNOITSKEN',
#    '@OdiousRepeater',
#    '@OmegaLiquidX',
#    '@Papapishu',
#    '@Polygon',
#    '@RaygunBrown',
#    '@RealBenGilbert',
#    '@RowanKaiser',
#    '@RussFrushtick',
#    '@SamitSarkar',
#    '@Seraxia',
#    '@Serrels',
#    '@ShaneWatch',
#    '@SimonParkin',
#    '@StuHorvath',
#    '@SusanArendt',
#    '@TheKevinDent',
#    '@TheWesterFront',
#    '@The_B',
#    '@Totalbiscuit',
#    '@WesPhillips',
#    '@adamharshberger',
#    '@aeazel',
#    '@aegies',
#    '@afraidtomerge',
#    '@alex_navarro',
#    '@alexrubens',
#    '@allenmmurray',
#    '@beachonthemoon',
#    '@bonzrat',
#    '@botherer',
#    '@chrisfurniss',
#    '@chrisgrant',
#    '@chrisremo',
#    '@crecenteb',
#    '@ctplante',
#    '@danthat',
#    '@daphaknee',
#    '@desensitisation',
#    '@ebertchicago',
#    '@ecavalli',
#    '@emilynussbaum',
#    '@eurogamer',
#    '@flantz',
#    '@fullbright',
#    '@greggaliffa',
#    '@haroldgoldberg',
#    '@harveyjamestm',
#    '@hentaiphd',
#    '@ibogost',
#    '@jamesmielke',
#    '@jasonschreier',
#    '@jennatar',
#    '@joeljohnson',
#    '@jonathancoulton',
#    '@jwhdavison',
#    '@kirkhamilton',
#    '@kobunheat',
#    '@kotaku',
#    '@leighalexander',
#    '@lrcomic',
#    '@lynchtacular',
#    '@m_spitz',
#    '@manveerheir',
#    '@mareodomo',
#    '@mathewkumar',
#    '@matthewrex',
#    '@misterbrilliant',
#    '@mittense',
#    '@mkrpata',
#    '@ncroal',
#    '@notch',
#    '@owengood',
#    '@patlike',
#    '@patrickklepek',
#    '@pkollar',
#    '@pmolyneux',
#    '@reddit)',
#    '@rich_lem',
#    '@rockpapershot',
#    '@russpitts',
#    '@scxzor',
#    '@shun_geki_satsu',
#    '@stephentotilo',
#    '@steveh11',
#    '@the1console',
#    '@therealcliffyb',
#    '@tole_cover',
#    '@tombramwell',
#    '@traceylien',
#    '@willsmith',
#    '@wilw'})]

# %%
user_pairs_rdd = feats.cartesian(feats).filter(lambda x: x[0][0] < x[1][0])
similarities_rdd = user_pairs_rdd.map(lambda x: (x[0][0], x[1][0], cosine_similarity(x[0][1], x[1][1])))

# %%
user_pairs_rdd.take(5)
